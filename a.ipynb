# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("fm.csv")

# Filter rows where the "MH_id" column equals 171377

df.head()
# Out:
# /tmp/ipykernel_29070/3616315796.py:4: DtypeWarning: Columns (14,16,18,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("fm.csv")
#                                                  id mp_requested_date  \
# 3842315614 2024-02-14 11:06:09  GorakhpurHub_GOP_PL         Gorakhpur
# 3842962395 2024-02-14 12:36:10  GorakhpurHub_GOP_PL         Gorakhpur
# 3842962536 2024-02-14 12:36:20  GorakhpurHub_GOP_PL         Gorakhpur
# 3842246676 2024-02-14 10:59:42  GorakhpurHub_GOP_PL         Gorakhpur
# 3829387250 2024-02-10 10:39:57  GorakhpurHub_GOP_PL         Gorakhpur
#
#                                fulfillmentFacilityId  PH_City PH_Zone  \
# 3842315614 2024-02-14 11:06:09                 North   104309      B1
# 3842962395 2024-02-14 12:36:10                 North   104309      B1
# 3842962536 2024-02-14 12:36:20                 North   104309      B1
# 3842246676 2024-02-14 10:59:42                 North   104309      B1
# ...

# %%
ykb = df[df["PH_City"] == 171377]

print("Unique MH_id values:", df["MH_id"].unique())

print("Number of rows in ykb DataFrame:", len(ykb))

# Print the first few rows of the filtered DataFrame
print("First few rows of ykb DataFrame:")
print(ykb.head())

# Write the filtered DataFrame to a CSV file
ykb.to_csv('ykb.csv', index=False)
# Out:
# Unique MH_id values: ['created' 'out_for_pickup' 'received_at_seller' 'dispatched_to_ph'
#  'received_at_ph' 'pickup_reattempt' 'dispatched_to_mh' 'received_at_mh']
# Number of rows in ykb DataFrame: 394619
# First few rows of ykb DataFrame:
#                                               id mp_requested_date  \
# 3840452790 2024-02-13 15:49:11  RohtakHub_ROH_PL            Rohtak
# 3843280215 2024-02-14 14:42:49  RohtakHub_ROH_PL            Rohtak
# 3843349699 2024-02-14 14:42:50  RohtakHub_ROH_PL            Rohtak
# 3843491577 2024-02-14 14:58:44  RohtakHub_ROH_PL            Rohtak
# 3843455607 2024-02-14 16:45:28  RohtakHub_ROH_PL            Rohtak
#
#                                fulfillmentFacilityId  PH_City PH_Zone  \
# 3840452790 2024-02-13 15:49:11                 North   171377      B5
# 3843280215 2024-02-14 14:42:49                 North   171377      B5
# 3843349699 2024-02-14 14:42:50                 North   171377      B5
# ...

# %%
b5 = ykb[ykb["PH_Zone"]  == "B5"]

print(f"B5 Count: " , b5["status"].unique())


b5.to_csv("b5.csv" , index=False)
# Out:
# B5 Count:  ['FMPC3466592825' 'FMPC3468800474' 'FMPC3468804473' ... 'FMPP2164708479'
#  'FMPP2164722492' 'OIPC0014682547']

# %%
b5_shipments  =  b5[["status"]]

b5_shipments.to_csv("b5_shipments.csv" , index=False)
